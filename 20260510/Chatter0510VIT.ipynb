# %%
import random
import numpy as np
import torch

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    # For CUDA determinism (optional but recommended)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True  # slower but repeatable
    torch.backends.cudnn.benchmark = False     # turn off auto-tuning

# %% [markdown]
# # 1. Load Data

# %%
import numpy as np

data = np.load("GAF_ReSplitDatasets.npz")

X_train = data["X_train"]
y_train = data["y_train"]

X_val = data["X_val"]
y_val = data["y_val"]

X_test = data["X_test"]
y_test = data["y_test"]

# %%
import matplotlib.pyplot as plt

def plot_gaf_sample_channels(X_data, y_data, sample_idx=0, cmap='viridis'):
    sample = X_data[sample_idx]  # shape: (7, 64, 64)
    label = y_data[sample_idx]

    fig, axs = plt.subplots(1, 7, figsize=(20, 3))
    for ch in range(7):
        axs[ch].imshow(sample[ch], cmap=cmap)
        axs[ch].axis('off')
        axs[ch].set_title(f"Channel {ch+1}")
    
    fig.suptitle(f"Sample #{sample_idx} - Label: {label}", fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
plot_gaf_sample_channels(X_train, y_train, sample_idx=0)

# %%
import torch
from torch.utils.data import Dataset

class GAFDataset(Dataset):
    def __init__(self, X, y, transform=None):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
        self.transform = transform  # optional: normalize or augment

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.transform:
            x = self.transform(x)
        return x, self.y[idx]

# %%
set_seed(42)

# %%
from torch.utils.data import DataLoader

train_dataset = GAFDataset(X_train, y_train)
val_dataset   = GAFDataset(X_val, y_val)
test_dataset  = GAFDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # 2 Model Training

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import os


# =========================================================
# 1. 基本设置
# =========================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

npz_path = "GAF_ReSplitDatasets.npz"

batch_size = 32
num_epochs = 500
learning_rate = 5e-5
weight_decay = 1e-4
patience = 40

save_path = "best_gaf_cnn_vit_mlp_model.pth"


# =========================================================
# 2. 读取 npz 数据
# =========================================================

data = np.load(npz_path)

X_train = data["X_train"]
y_train = data["y_train"]

X_val = data["X_val"]
y_val = data["y_val"]

X_test = data["X_test"]
y_test = data["y_test"]

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)


# =========================================================
# 3. 标签处理
# =========================================================
# 如果 y 是 one-hot，例如 shape = (N, num_classes)，转成类别编号
# 如果 y 已经是 (N,)，则不变

if len(y_train.shape) > 1:
    y_train = np.argmax(y_train, axis=1)
    y_val = np.argmax(y_val, axis=1)
    y_test = np.argmax(y_test, axis=1)

y_train = y_train.astype(np.int64)
y_val = y_val.astype(np.int64)
y_test = y_test.astype(np.int64)

num_classes = len(np.unique(y_train))
print("Number of classes:", num_classes)


# =========================================================
# 4. 数据集定义
# =========================================================

class GAFDataset(Dataset):
    def __init__(self, X, y):
        """
        支持以下几种输入格式：
        1. (N, 64, 64, 7)  -> NHWC
        2. (N, 7, 64, 64)  -> NCHW
        3. (N, 64, 7, 64)  -> NHCW
        """
        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)

        print("Original X shape in Dataset:", self.X.shape)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]

        # 情况 1: x = (64, 64, 7)
        # 转成 (7, 64, 64)
        if x.shape == (64, 64, 7):
            x = np.transpose(x, (2, 0, 1))

        # 情况 2: x = (7, 64, 64)
        # 已经是 PyTorch 格式，不需要改
        elif x.shape == (7, 64, 64):
            pass

        # 情况 3: x = (64, 7, 64)
        # 转成 (7, 64, 64)
        elif x.shape == (64, 7, 64):
            x = np.transpose(x, (1, 0, 2))

        else:
            raise ValueError(f"Unexpected input shape: {x.shape}")

        y = self.y[idx]

        x = torch.tensor(x, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.long)

        return x, y


train_dataset = GAFDataset(X_train, y_train)
val_dataset = GAFDataset(X_val, y_val)
test_dataset = GAFDataset(X_test, y_test)

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0
)


# =========================================================
# 5. CNN + ViT + MLP 模型
# =========================================================

class CNNFeatureExtractor(nn.Module):
    def __init__(self, in_channels=7, out_channels=128):
        super(CNNFeatureExtractor, self).__init__()

        self.cnn = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            # 64 x 64 -> 32 x 32

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            # 32 x 32 -> 16 x 16

            nn.Conv2d(64, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
            # 输出: 128 x 16 x 16
        )

    def forward(self, x):
        return self.cnn(x)


class PatchEmbedding(nn.Module):
    def __init__(self, in_channels=128, embed_dim=128, patch_size=4):
        super(PatchEmbedding, self).__init__()

        self.patch_size = patch_size

        self.proj = nn.Conv2d(
            in_channels=in_channels,
            out_channels=embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        """
        x shape: (B, C, H, W)
        after projection: (B, embed_dim, H/patch, W/patch)
        flatten to: (B, num_patches, embed_dim)
        """
        x = self.proj(x)
        x = x.flatten(2)
        x = x.transpose(1, 2)
        return x


class GAF_CNN_ViT_MLP(nn.Module):
    def __init__(
        self,
        in_channels=7,
        num_classes=2,
        cnn_out_channels=128,
        embed_dim=128,
        patch_size=4,
        num_heads=4,
        num_transformer_layers=2,
        mlp_hidden_dim=128,
        dropout=0.3
    ):
        super(GAF_CNN_ViT_MLP, self).__init__()

        self.cnn = CNNFeatureExtractor(
            in_channels=in_channels,
            out_channels=cnn_out_channels
        )

        self.patch_embed = PatchEmbedding(
            in_channels=cnn_out_channels,
            embed_dim=embed_dim,
            patch_size=patch_size
        )

        # CNN 输出是 16 x 16
        # patch_size = 4 后，patch 数量为 4 x 4 = 16
        num_patches = (16 // patch_size) * (16 // patch_size)

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.pos_embedding = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=embed_dim * 4,
            dropout=dropout,
            batch_first=True,
            activation="gelu"
        )

        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_transformer_layers
        )

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(embed_dim),
            nn.Linear(embed_dim, mlp_hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(mlp_hidden_dim, num_classes)
        )

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        nn.init.trunc_normal_(self.pos_embedding, std=0.02)

    def forward(self, x):
        """
        input x: (B, 7, 64, 64)
        """
        x = self.cnn(x)
        x = self.patch_embed(x)

        batch_size = x.shape[0]

        cls_tokens = self.cls_token.expand(batch_size, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)

        x = x + self.pos_embedding

        x = self.transformer(x)

        cls_output = x[:, 0]

        out = self.mlp_head(cls_output)

        return out


# =========================================================
# 6. 建立模型
# =========================================================

model = GAF_CNN_ViT_MLP(
    in_channels=7,
    num_classes=num_classes,
    cnn_out_channels=128,
    embed_dim=128,
    patch_size=4,
    num_heads=4,
    num_transformer_layers=2,
    mlp_hidden_dim=128,
    dropout=0.3
).to(device)

print(model)


# =========================================================
# 7. 损失函数和优化器
# =========================================================

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=100
)


# =========================================================
# 8. 训练与验证函数
# =========================================================

def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_loss = 0.0
    all_preds = []
    all_labels = []

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()

        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * X_batch.size(0)

        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(y_batch.detach().cpu().numpy())

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = accuracy_score(all_labels, all_preds)

    return epoch_loss, epoch_acc


def evaluate(model, loader, criterion, device):
    model.eval()

    running_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            running_loss += loss.item() * X_batch.size(0)

            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.detach().cpu().numpy())
            all_labels.extend(y_batch.detach().cpu().numpy())

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = accuracy_score(all_labels, all_preds)

    return epoch_loss, epoch_acc, np.array(all_labels), np.array(all_preds)


# =========================================================
# 9. 正式训练
# =========================================================

best_val_loss = np.inf
early_stop_counter = 0

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": []
}

for epoch in range(num_epochs):

    train_loss, train_acc = train_one_epoch(
        model,
        train_loader,
        criterion,
        optimizer,
        device
    )

    val_loss, val_acc, _, _ = evaluate(
        model,
        val_loader,
        criterion,
        device
    )

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)

    print(
        f"Epoch [{epoch + 1:03d}/{num_epochs}] "
        f"Train Loss: {train_loss:.4f} | "
        f"Train Acc: {train_acc:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Val Acc: {val_acc:.4f}"
    )

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stop_counter = 0

        torch.save(
            {
                "model_state_dict": model.state_dict(),
                "num_classes": num_classes,
                "history": history
            },
            save_path
        )

        print("Best model saved.")

    else:
        early_stop_counter += 1
        print(f"Early stopping counter: {early_stop_counter}/{patience}")

        # if early_stop_counter >= patience:
        #     print("Early stopping triggered.")
        #     break


# =========================================================
# 10. 测试集评估
# =========================================================

checkpoint = torch.load(save_path, map_location=device)
model.load_state_dict(checkpoint["model_state_dict"])

test_loss, test_acc, y_true, y_pred = evaluate(
    model,
    test_loader,
    criterion,
    device
)

print("\n================ Test Result ================")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)

print("\nClassification Report:")
print(classification_report(y_true, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))


# =========================================================
# 11. 保存训练历史
# =========================================================

np.savez(
    "training_history_gaf_cnn_vit_mlp.npz",
    train_loss=np.array(history["train_loss"]),
    train_acc=np.array(history["train_acc"]),
    val_loss=np.array(history["val_loss"]),
    val_acc=np.array(history["val_acc"])
)

print("\nTraining history saved.")
print("Best model saved as:", save_path)
# Out:
# Using device: cuda
# X_train shape: (7679, 7, 64, 64)
# y_train shape: (7679,)
# X_val shape: (961, 7, 64, 64)
# y_val shape: (961,)
# X_test shape: (960, 7, 64, 64)
# y_test shape: (960,)
# Number of classes: 3
# Original X shape in Dataset: (7679, 7, 64, 64)
# Original X shape in Dataset: (961, 7, 64, 64)
# Original X shape in Dataset: (960, 7, 64, 64)
# GAF_CNN_ViT_MLP(
#   (cnn): CNNFeatureExtractor(
#     (cnn): Sequential(
#       (0): Conv2d(7, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU(inplace=True)
#       (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#     )
#   )
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# Epoch [001/500] Train Loss: 0.6687 | Train Acc: 0.7247 | Val Loss: 0.5627 | Val Acc: 0.7523
# Best model saved.
# Epoch [002/500] Train Loss: 0.3603 | Train Acc: 0.8548 | Val Loss: 0.2781 | Val Acc: 0.8897
# Best model saved.
# Epoch [003/500] Train Loss: 0.2825 | Train Acc: 0.8814 | Val Loss: 0.2439 | Val Acc: 0.8980
# Best model saved.
500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4193 | Val Acc: 0.9469
# Early stopping counter: 213/40
# Epoch [238/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.4364 | Val Acc: 0.9469
# Early stopping counter: 214/40
# Epoch [239/500] Train Loss: 0.0003 | Train Acc: 1.0000 | Val Loss: 0.4323 | Val Acc: 0.9501
# Early stopping counter: 215/40
# Epoch [240/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.4356 | Val Acc: 0.9459
# Early stopping counter: 216/40
# Epoch [241/500] Train Loss: 0.0030 | Train Acc: 0.9995 | Val Loss: 0.4959 | Val Acc: 0.9396
# Early stopping counter: 217/40
# Epoch [242/500] Train Loss: 0.0007 | Train Acc: 0.9997 | Val Loss: 0.4332 | Val Acc: 0.9459
# Early stopping counter: 218/40
# Epoch [243/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4401 | Val Acc: 0.9448
# Early stopping counter: 219/40
# Epoch [244/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4357 | Val Acc: 0.9469
# Early stopping counter: 220/40
# Epoch [245/500] Train Loss: 0.0005 | Train Acc: 0.9997 | Val Loss: 0.4319 | Val Acc: 0.9501
# Early stopping counter: 221/40
# Epoch [246/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4323 | Val Acc: 0.9501
# Early stopping counter: 222/40
# Epoch [247/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4379 | Val Acc: 0.9480
# Early stopping counter: 223/40
# Epoch [248/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4492 | Val Acc: 0.9448
# Early stopping counter: 224/40
# Epoch [249/500] Train Loss: 0.0006 | Train Acc: 0.9999 | Val Loss: 0.4479 | Val Acc: 0.9480
# Early stopping counter: 225/40
# Epoch [250/500] Train Loss: 0.0008 | Train Acc: 0.9997 | Val Loss: 0.4224 | Val Acc: 0.9480
# Early stopping counter: 226/40
# Epoch [251/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4363 | Val Acc: 0.9448
# Early stopping counter: 227/40
# Epoch [252/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4286 | Val Acc: 0.9469
# Early stopping counter: 228/40
# Epoch [253/500] Train Loss: 0.0007 | Train Acc: 0.9999 | Val Loss: 0.4217 | Val Acc: 0.9469
# Early stopping counter: 229/40
# Epoch [254/500] Train Loss: 0.0010 | Train Acc: 0.9997 | Val Loss: 0.4656 | Val Acc: 0.9469
# Early stopping counter: 230/40
# Epoch [255/500] Train Loss: 0.0016 | Train Acc: 0.9993 | Val Loss: 0.4655 | Val Acc: 0.9490
# Early stopping counter: 231/40
# Epoch [256/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4610 | Val Acc: 0.9501
# Early stopping counter: 232/40
# Epoch [257/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4474 | Val Acc: 0.9490
# Early stopping counter: 233/40
# Epoch [258/500] Train Loss: 0.0005 | Train Acc: 0.9999 | Val Loss: 0.4689 | Val Acc: 0.9469
# Early stopping counter: 234/40
# Epoch [259/500] Train Loss: 0.0007 | Train Acc: 0.9996 | Val Loss: 0.4347 | Val Acc: 0.9501
# Early stopping counter: 235/40
# Epoch [260/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.4344 | Val Acc: 0.9501
# Early stopping counter: 236/40
# Epoch [261/500] Train Loss: 0.0006 | Train Acc: 0.9997 | Val Loss: 0.4275 | Val Acc: 0.9490
# Early stopping counter: 237/40
# Epoch [262/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4351 | Val Acc: 0.9511
# Early stopping counter: 238/40
# Epoch [263/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4394 | Val Acc: 0.9501
# Early stopping counter: 239/40
# Epoch [264/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4304 | Val Acc: 0.9501
# Early stopping counter: 240/40
# Epoch [265/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4309 | Val Acc: 0.9501
# Early stopping counter: 241/40
# Epoch [266/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4537 | Val Acc: 0.9490
# Early stopping counter: 242/40
# Epoch [267/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4237 | Val Acc: 0.9511
# Early stopping counter: 243/40
# Epoch [268/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4348 | Val Acc: 0.9490
# Early stopping counter: 244/40
# Epoch [269/500] Train Loss: 0.0007 | Train Acc: 0.9997 | Val Loss: 0.4948 | Val Acc: 0.9438
# Early stopping counter: 245/40
# Epoch [270/500] Train Loss: 0.0007 | Train Acc: 0.9997 | Val Loss: 0.4703 | Val Acc: 0.9490
# Early stopping counter: 246/40
# Epoch [271/500] Train Loss: 0.0034 | Train Acc: 0.9991 | Val Loss: 0.4673 | Val Acc: 0.9438
# Early stopping counter: 247/40
# Epoch [272/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4736 | Val Acc: 0.9428
# Early stopping counter: 248/40
# Epoch [273/500] Train Loss: 0.0014 | Train Acc: 0.9997 | Val Loss: 0.4613 | Val Acc: 0.9511
# Early stopping counter: 249/40
# Epoch [274/500] Train Loss: 0.0003 | Train Acc: 0.9999 | Val Loss: 0.4882 | Val Acc: 0.9501
# Early stopping counter: 250/40
# Epoch [275/500] Train Loss: 0.0018 | Train Acc: 0.9996 | Val Loss: 0.4933 | Val Acc: 0.9511
# Early stopping counter: 251/40
# Epoch [276/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4752 | Val Acc: 0.9521
# Early stopping counter: 252/40
# Epoch [277/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4840 | Val Acc: 0.9511
# Early stopping counter: 253/40
# Epoch [278/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.4715 | Val Acc: 0.9511
# Early stopping counter: 254/40
# Epoch [279/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4736 | Val Acc: 0.9511
# Early stopping counter: 255/40
# Epoch [280/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4926 | Val Acc: 0.9532
# Early stopping counter: 256/40
# Epoch [281/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4804 | Val Acc: 0.9521
# Early stopping counter: 257/40
# Epoch [282/500] Train Loss: 0.0004 | Train Acc: 0.9999 | Val Loss: 0.4801 | Val Acc: 0.9501
# Early stopping counter: 258/40
# Epoch [283/500] Train Loss: 0.0008 | Train Acc: 0.9997 | Val Loss: 0.5554 | Val Acc: 0.9459
# Early stopping counter: 259/40
# Epoch [284/500] Train Loss: 0.0029 | Train Acc: 0.9995 | Val Loss: 0.4727 | Val Acc: 0.9480
# Early stopping counter: 260/40
# Epoch [285/500] Train Loss: 0.0009 | Train Acc: 0.9997 | Val Loss: 0.4830 | Val Acc: 0.9480
# Early stopping counter: 261/40
# Epoch [286/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4471 | Val Acc: 0.9480
# Early stopping counter: 262/40
# Epoch [287/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4511 | Val Acc: 0.9521
# Early stopping counter: 263/40
# Epoch [288/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.4797 | Val Acc: 0.9501
# Early stopping counter: 264/40
# Epoch [289/500] Train Loss: 0.0006 | Train Acc: 0.9997 | Val Loss: 0.4628 | Val Acc: 0.9480
# Early stopping counter: 265/40
# Epoch [290/500] Train Loss: 0.0017 | Train Acc: 0.9992 | Val Loss: 0.4910 | Val Acc: 0.9459
# Early stopping counter: 266/40
# Epoch [291/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4843 | Val Acc: 0.9459
# Early stopping counter: 267/40
# Epoch [292/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.4987 | Val Acc: 0.9448
# Early stopping counter: 268/40
# Epoch [293/500] Train Loss: 0.0005 | Train Acc: 0.9999 | Val Loss: 0.4891 | Val Acc: 0.9417
# Early stopping counter: 269/40
# Epoch [294/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.5137 | Val Acc: 0.9448
# Early stopping counter: 270/40
# Epoch [295/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4919 | Val Acc: 0.9428
# Early stopping counter: 271/40
# Epoch [296/500] Train Loss: 0.0025 | Train Acc: 0.9993 | Val Loss: 0.5246 | Val Acc: 0.9448
# Early stopping counter: 272/40
# Epoch [297/500] Train Loss: 0.0004 | Train Acc: 0.9999 | Val Loss: 0.4936 | Val Acc: 0.9469
# Early stopping counter: 273/40
# Epoch [298/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4737 | Val Acc: 0.9501
# Early stopping counter: 274/40
# Epoch [299/500] Train Loss: 0.0003 | Train Acc: 0.9997 | Val Loss: 0.4617 | Val Acc: 0.9511
# Early stopping counter: 275/40
# Epoch [300/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4712 | Val Acc: 0.9448
# Early stopping counter: 276/40
# Epoch [301/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.4752 | Val Acc: 0.9480
# Early stopping counter: 277/40
# Epoch [302/500] Train Loss: 0.0017 | Train Acc: 0.9996 | Val Loss: 0.4751 | Val Acc: 0.9490
# Early stopping counter: 278/40
# Epoch [303/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4621 | Val Acc: 0.9511
# Early stopping counter: 279/40
# Epoch [304/500] Train Loss: 0.0004 | Train Acc: 0.9999 | Val Loss: 0.4864 | Val Acc: 0.9501
# Early stopping counter: 280/40
# Epoch [305/500] Train Loss: 0.0012 | Train Acc: 0.9996 | Val Loss: 0.4436 | Val Acc: 0.9542
# Early stopping counter: 281/40
# Epoch [306/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4461 | Val Acc: 0.9532
# Early stopping counter: 282/40
# Epoch [307/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4449 | Val Acc: 0.9532
# Early stopping counter: 283/40
# Epoch [308/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.4474 | Val Acc: 0.9511
# Early stopping counter: 284/40
# Epoch [309/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4619 | Val Acc: 0.9501
# Early stopping counter: 285/40
# Epoch [310/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4661 | Val Acc: 0.9490
# Early stopping counter: 286/40
# Epoch [311/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4598 | Val Acc: 0.9511
# Early stopping counter: 287/40
# Epoch [312/500] Train Loss: 0.0005 | Train Acc: 0.9997 | Val Loss: 0.5002 | Val Acc: 0.9469
# Early stopping counter: 288/40
# Epoch [313/500] Train Loss: 0.0005 | Train Acc: 0.9997 | Val Loss: 0.4703 | Val Acc: 0.9501
# Early stopping counter: 289/40
# Epoch [314/500] Train Loss: 0.0004 | Train Acc: 0.9999 | Val Loss: 0.4949 | Val Acc: 0.9501
# Early stopping counter: 290/40
# Epoch [315/500] Train Loss: 0.0011 | Train Acc: 0.9999 | Val Loss: 0.4827 | Val Acc: 0.9521
# Early stopping counter: 291/40
# Epoch [316/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4730 | Val Acc: 0.9532
# Early stopping counter: 292/40
# Epoch [317/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4773 | Val Acc: 0.9532
# Early stopping counter: 293/40
# Epoch [318/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4787 | Val Acc: 0.9532
# Early stopping counter: 294/40
# Epoch [319/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4789 | Val Acc: 0.9532
# Early stopping counter: 295/40
# Epoch [320/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4739 | Val Acc: 0.9532
# Early stopping counter: 296/40
# Epoch [321/500] Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.5312 | Val Acc: 0.9396
# Early stopping counter: 297/40
# Epoch [322/500] Train Loss: 0.0009 | Train Acc: 0.9996 | Val Loss: 0.5259 | Val Acc: 0.9448
# Early stopping counter: 298/40
# Epoch [323/500] Train Loss: 0.0020 | Train Acc: 0.9996 | Val Loss: 0.4863 | Val Acc: 0.9480
# Early stopping counter: 299/40
# Epoch [324/500] Train Loss: 0.0017 | Train Acc: 0.9996 | Val Loss: 0.4967 | Val Acc: 0.9469
# Early stopping counter: 300/40
# Epoch [325/500] Train Loss: 0.0017 | Train Acc: 0.9996 | Val Loss: 0.4591 | Val Acc: 0.9501
# Early stopping counter: 301/40
# Epoch [326/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4561 | Val Acc: 0.9511
# Early stopping counter: 302/40
# Epoch [327/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4862 | Val Acc: 0.9511
# Early stopping counter: 303/40
# Epoch [328/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4626 | Val Acc: 0.9532
# Early stopping counter: 304/40
# Epoch [329/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4492 | Val Acc: 0.9542
# Early stopping counter: 305/40
# Epoch [330/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4569 | Val Acc: 0.9521
# Early stopping counter: 306/40
# Epoch [331/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4599 | Val Acc: 0.9532
# Early stopping counter: 307/40
# Epoch [332/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.4507 | Val Acc: 0.9501
# Early stopping counter: 308/40
# Epoch [333/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4359 | Val Acc: 0.9511
# Early stopping counter: 309/40
# Epoch [334/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4393 | Val Acc: 0.9511
# Early stopping counter: 310/40
# Epoch [335/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4415 | Val Acc: 0.9501
# Early stopping counter: 311/40
# Epoch [336/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4362 | Val Acc: 0.9532
# Early stopping counter: 312/40
# Epoch [337/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4502 | Val Acc: 0.9542
# Early stopping counter: 313/40
# Epoch [338/500] Train Loss: 0.0004 | Train Acc: 0.9999 | Val Loss: 0.4491 | Val Acc: 0.9511
# Early stopping counter: 314/40
# Epoch [339/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4451 | Val Acc: 0.9521
# Early stopping counter: 315/40
# Epoch [340/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4417 | Val Acc: 0.9521
# Early stopping counter: 316/40
# Epoch [341/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4461 | Val Acc: 0.9542
# Early stopping counter: 317/40
# Epoch [342/500] Train Loss: 0.0008 | Train Acc: 0.9996 | Val Loss: 0.4341 | Val Acc: 0.9511
# Early stopping counter: 318/40
# Epoch [343/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4408 | Val Acc: 0.9501
# Early stopping counter: 319/40
# Epoch [344/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4778 | Val Acc: 0.9448
# Early stopping counter: 320/40
# Epoch [345/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4542 | Val Acc: 0.9511
# Early stopping counter: 321/40
# Epoch [346/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4460 | Val Acc: 0.9480
# Early stopping counter: 322/40
# Epoch [347/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4542 | Val Acc: 0.9469
# Early stopping counter: 323/40
# Epoch [348/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4511 | Val Acc: 0.9490
# Early stopping counter: 324/40
# Epoch [349/500] Train Loss: 0.0004 | Train Acc: 0.9999 | Val Loss: 0.4797 | Val Acc: 0.9501
# Early stopping counter: 325/40
# Epoch [350/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4726 | Val Acc: 0.9511
# Early stopping counter: 326/40
# Epoch [351/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4687 | Val Acc: 0.9490
# Early stopping counter: 327/40
# Epoch [352/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4674 | Val Acc: 0.9480
# Early stopping counter: 328/40
# Epoch [353/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4693 | Val Acc: 0.9511
# Early stopping counter: 329/40
# Epoch [354/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4762 | Val Acc: 0.9511
# Early stopping counter: 330/40
# Epoch [355/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4683 | Val Acc: 0.9480
# Early stopping counter: 331/40
# Epoch [356/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4667 | Val Acc: 0.9448
# Early stopping counter: 332/40
# Epoch [357/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4731 | Val Acc: 0.9480
# Early stopping counter: 333/40
# Epoch [358/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4677 | Val Acc: 0.9480
# Early stopping counter: 334/40
# Epoch [359/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4686 | Val Acc: 0.9490
# Early stopping counter: 335/40
# Epoch [360/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4673 | Val Acc: 0.9480
# Early stopping counter: 336/40
# Epoch [361/500] Train Loss: 0.0003 | Train Acc: 0.9997 | Val Loss: 0.4769 | Val Acc: 0.9480
# Early stopping counter: 337/40
# Epoch [362/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4815 | Val Acc: 0.9501
# Early stopping counter: 338/40
# Epoch [363/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4921 | Val Acc: 0.9438
# Early stopping counter: 339/40
# Epoch [364/500] Train Loss: 0.0003 | Train Acc: 0.9999 | Val Loss: 0.4890 | Val Acc: 0.9480
# Early stopping counter: 340/40
# Epoch [365/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.4860 | Val Acc: 0.9480
# Early stopping counter: 341/40
# Epoch [366/500] Train Loss: 0.0003 | Train Acc: 0.9999 | Val Loss: 0.4769 | Val Acc: 0.9511
# Early stopping counter: 342/40
# Epoch [367/500] Train Loss: 0.0011 | Train Acc: 0.9997 | Val Loss: 0.4897 | Val Acc: 0.9490
# Early stopping counter: 343/40
# Epoch [368/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4836 | Val Acc: 0.9501
# Early stopping counter: 344/40
# Epoch [369/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4893 | Val Acc: 0.9469
# Early stopping counter: 345/40
# Epoch [370/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4857 | Val Acc: 0.9490
# Early stopping counter: 346/40
# Epoch [371/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4928 | Val Acc: 0.9469
# Early stopping counter: 347/40
# Epoch [372/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4860 | Val Acc: 0.9490
# Early stopping counter: 348/40
# Epoch [373/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4873 | Val Acc: 0.9501
# Early stopping counter: 349/40
# Epoch [374/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4869 | Val Acc: 0.9501
# Early stopping counter: 350/40
# Epoch [375/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4951 | Val Acc: 0.9469
# Early stopping counter: 351/40
# Epoch [376/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4946 | Val Acc: 0.9501
# Early stopping counter: 352/40
# Epoch [377/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.4991 | Val Acc: 0.9480
# Early stopping counter: 353/40
# Epoch [378/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.4940 | Val Acc: 0.9480
# Early stopping counter: 354/40
# Epoch [379/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5004 | Val Acc: 0.9459
# Early stopping counter: 355/40
# Epoch [380/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.4849 | Val Acc: 0.9511
# Early stopping counter: 356/40
# Epoch [381/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.4942 | Val Acc: 0.9521
# Early stopping counter: 357/40
# Epoch [382/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5034 | Val Acc: 0.9480
# Early stopping counter: 358/40
# Epoch [383/500] Train Loss: 0.0006 | Train Acc: 0.9997 | Val Loss: 0.5165 | Val Acc: 0.9469
# Early stopping counter: 359/40
# Epoch [384/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5224 | Val Acc: 0.9448
# Early stopping counter: 360/40
# Epoch [385/500] Train Loss: 0.0003 | Train Acc: 0.9999 | Val Loss: 0.5020 | Val Acc: 0.9480
# Early stopping counter: 361/40
# Epoch [386/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5110 | Val Acc: 0.9511
# Early stopping counter: 362/40
# Epoch [387/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5030 | Val Acc: 0.9501
# Early stopping counter: 363/40
# Epoch [388/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5080 | Val Acc: 0.9501
# Early stopping counter: 364/40
# Epoch [389/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5134 | Val Acc: 0.9501
# Early stopping counter: 365/40
# Epoch [390/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5075 | Val Acc: 0.9501
# Early stopping counter: 366/40
# Epoch [391/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5088 | Val Acc: 0.9501
# Early stopping counter: 367/40
# Epoch [392/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5194 | Val Acc: 0.9490
# Early stopping counter: 368/40
# Epoch [393/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5183 | Val Acc: 0.9490
# Early stopping counter: 369/40
# Epoch [394/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5238 | Val Acc: 0.9480
# Early stopping counter: 370/40
# Epoch [395/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5216 | Val Acc: 0.9480
# Early stopping counter: 371/40
# Epoch [396/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5197 | Val Acc: 0.9501
# Early stopping counter: 372/40
# Epoch [397/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5127 | Val Acc: 0.9501
# Early stopping counter: 373/40
# Epoch [398/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.5204 | Val Acc: 0.9501
# Early stopping counter: 374/40
# Epoch [399/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.5560 | Val Acc: 0.9480
# Early stopping counter: 375/40
# Epoch [400/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.5341 | Val Acc: 0.9501
# Early stopping counter: 376/40
# Epoch [401/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5284 | Val Acc: 0.9511
# Early stopping counter: 377/40
# Epoch [402/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5243 | Val Acc: 0.9511
# Early stopping counter: 378/40
# Epoch [403/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5236 | Val Acc: 0.9511
# Early stopping counter: 379/40
# Epoch [404/500] Train Loss: 0.0009 | Train Acc: 0.9999 | Val Loss: 0.5139 | Val Acc: 0.9511
# Early stopping counter: 380/40
# Epoch [405/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5124 | Val Acc: 0.9490
# Early stopping counter: 381/40
# Epoch [406/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5021 | Val Acc: 0.9480
# Early stopping counter: 382/40
# Epoch [407/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5001 | Val Acc: 0.9501
# Early stopping counter: 383/40
# Epoch [408/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5045 | Val Acc: 0.9501
# Early stopping counter: 384/40
# Epoch [409/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.5306 | Val Acc: 0.9448
# Early stopping counter: 385/40
# Epoch [410/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5361 | Val Acc: 0.9448
# Early stopping counter: 386/40
# Epoch [411/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5256 | Val Acc: 0.9501
# Early stopping counter: 387/40
# Epoch [412/500] Train Loss: 0.0006 | Train Acc: 0.9999 | Val Loss: 0.5289 | Val Acc: 0.9501
# Early stopping counter: 388/40
# Epoch [413/500] Train Loss: 0.0011 | Train Acc: 0.9997 | Val Loss: 0.5335 | Val Acc: 0.9501
# Early stopping counter: 389/40
# Epoch [414/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5433 | Val Acc: 0.9501
# Early stopping counter: 390/40
# Epoch [415/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5347 | Val Acc: 0.9521
# Early stopping counter: 391/40
# Epoch [416/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.5263 | Val Acc: 0.9501
# Early stopping counter: 392/40
# Epoch [417/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5286 | Val Acc: 0.9521
# Early stopping counter: 393/40
# Epoch [418/500] Train Loss: 0.0008 | Train Acc: 0.9999 | Val Loss: 0.5648 | Val Acc: 0.9417
# Early stopping counter: 394/40
# Epoch [419/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5511 | Val Acc: 0.9448
# Early stopping counter: 395/40
# Epoch [420/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.5354 | Val Acc: 0.9480
# Early stopping counter: 396/40
# Epoch [421/500] Train Loss: 0.0019 | Train Acc: 0.9997 | Val Loss: 0.5321 | Val Acc: 0.9459
# Early stopping counter: 397/40
# Epoch [422/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5354 | Val Acc: 0.9459
# Early stopping counter: 398/40
# Epoch [423/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5346 | Val Acc: 0.9459
# Early stopping counter: 399/40
# Epoch [424/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5393 | Val Acc: 0.9469
# Early stopping counter: 400/40
# Epoch [425/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5352 | Val Acc: 0.9469
# Early stopping counter: 401/40
# Epoch [426/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5704 | Val Acc: 0.9438
# Early stopping counter: 402/40
# Epoch [427/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5505 | Val Acc: 0.9448
# Early stopping counter: 403/40
# Epoch [428/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5492 | Val Acc: 0.9448
# Early stopping counter: 404/40
# Epoch [429/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5521 | Val Acc: 0.9448
# Early stopping counter: 405/40
# Epoch [430/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5617 | Val Acc: 0.9480
# Early stopping counter: 406/40
# Epoch [431/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.5613 | Val Acc: 0.9448
# Early stopping counter: 407/40
# Epoch [432/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5601 | Val Acc: 0.9448
# Early stopping counter: 408/40
# Epoch [433/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5545 | Val Acc: 0.9480
# Early stopping counter: 409/40
# Epoch [434/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5600 | Val Acc: 0.9469
# Early stopping counter: 410/40
# Epoch [435/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5576 | Val Acc: 0.9448
# Early stopping counter: 411/40
# Epoch [436/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5615 | Val Acc: 0.9459
# Early stopping counter: 412/40
# Epoch [437/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.5501 | Val Acc: 0.9480
# Early stopping counter: 413/40
# Epoch [438/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5451 | Val Acc: 0.9490
# Early stopping counter: 414/40
# Epoch [439/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5479 | Val Acc: 0.9480
# Early stopping counter: 415/40
# Epoch [440/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5522 | Val Acc: 0.9469
# Early stopping counter: 416/40
# Epoch [441/500] Train Loss: 0.0002 | Train Acc: 0.9999 | Val Loss: 0.5434 | Val Acc: 0.9459
# Early stopping counter: 417/40
# Epoch [442/500] Train Loss: 0.0005 | Train Acc: 0.9997 | Val Loss: 0.5514 | Val Acc: 0.9448
# Early stopping counter: 418/40
# Epoch [443/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5483 | Val Acc: 0.9448
# Early stopping counter: 419/40
# Epoch [444/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5452 | Val Acc: 0.9448
# Early stopping counter: 420/40
# Epoch [445/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5410 | Val Acc: 0.9469
# Early stopping counter: 421/40
# Epoch [446/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5432 | Val Acc: 0.9438
# Early stopping counter: 422/40
# Epoch [447/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5527 | Val Acc: 0.9438
# Early stopping counter: 423/40
# Epoch [448/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5501 | Val Acc: 0.9438
# Early stopping counter: 424/40
# Epoch [449/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5505 | Val Acc: 0.9448
# Early stopping counter: 425/40
# Epoch [450/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5417 | Val Acc: 0.9480
# Early stopping counter: 426/40
# Epoch [451/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5381 | Val Acc: 0.9448
# Early stopping counter: 427/40
# Epoch [452/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5476 | Val Acc: 0.9459
# Early stopping counter: 428/40
# Epoch [453/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5434 | Val Acc: 0.9448
# Early stopping counter: 429/40
# Epoch [454/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5472 | Val Acc: 0.9438
# Early stopping counter: 430/40
# Epoch [455/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5481 | Val Acc: 0.9459
# Early stopping counter: 431/40
# Epoch [456/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5470 | Val Acc: 0.9459
# Early stopping counter: 432/40
# Epoch [457/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5503 | Val Acc: 0.9459
# Early stopping counter: 433/40
# Epoch [458/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5554 | Val Acc: 0.9438
# Early stopping counter: 434/40
# Epoch [459/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5492 | Val Acc: 0.9438
# Early stopping counter: 435/40
# Epoch [460/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.5519 | Val Acc: 0.9459
# Early stopping counter: 436/40
# Epoch [461/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5553 | Val Acc: 0.9490
# Early stopping counter: 437/40
# Epoch [462/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5397 | Val Acc: 0.9459
# Early stopping counter: 438/40
# Epoch [463/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5466 | Val Acc: 0.9480
# Early stopping counter: 439/40
# Epoch [464/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5473 | Val Acc: 0.9511
# Early stopping counter: 440/40
# Epoch [465/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5393 | Val Acc: 0.9490
# Early stopping counter: 441/40
# Epoch [466/500] Train Loss: 0.0003 | Train Acc: 0.9999 | Val Loss: 0.5373 | Val Acc: 0.9480
# Early stopping counter: 442/40
# Epoch [467/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5364 | Val Acc: 0.9511
# Early stopping counter: 443/40
# Epoch [468/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5379 | Val Acc: 0.9501
# Early stopping counter: 444/40
# Epoch [469/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5346 | Val Acc: 0.9501
# Early stopping counter: 445/40
# Epoch [470/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5402 | Val Acc: 0.9521
# Early stopping counter: 446/40
# Epoch [471/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5364 | Val Acc: 0.9511
# Early stopping counter: 447/40
# Epoch [472/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5389 | Val Acc: 0.9501
# Early stopping counter: 448/40
# Epoch [477/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5417 | Val Acc: 0.9511
# Early stopping counter: 453/40
# Epoch [478/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5391 | Val Acc: 0.9511
# Early stopping counter: 454/40
# Epoch [479/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.5378 | Val Acc: 0.9480
# Early stopping counter: 455/40
# Epoch [480/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5416 | Val Acc: 0.9480
# Early stopping counter: 456/40
# Epoch [481/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5427 | Val Acc: 0.9490
# Early stopping counter: 457/40
# Epoch [482/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5452 | Val Acc: 0.9480
# Early stopping counter: 458/40
# Epoch [483/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5400 | Val Acc: 0.9490
# Early stopping counter: 459/40
# Epoch [484/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5424 | Val Acc: 0.9480
# Early stopping counter: 460/40
# Epoch [485/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5470 | Val Acc: 0.9469
# Early stopping counter: 461/40
# Epoch [486/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5464 | Val Acc: 0.9490
# Early stopping counter: 462/40
# Epoch [487/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5406 | Val Acc: 0.9480
# Early stopping counter: 463/40
# Epoch [488/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5471 | Val Acc: 0.9511
# Early stopping counter: 464/40
# Epoch [489/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5410 | Val Acc: 0.9521
# Early stopping counter: 465/40
# Epoch [490/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5395 | Val Acc: 0.9521
# Early stopping counter: 466/40
# Epoch [491/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5470 | Val Acc: 0.9532
# Early stopping counter: 467/40
# Epoch [492/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5517 | Val Acc: 0.9501
# Early stopping counter: 468/40
# Epoch [493/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5503 | Val Acc: 0.9521
# Early stopping counter: 469/40
# Epoch [494/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5438 | Val Acc: 0.9542
# Early stopping counter: 470/40
# Epoch [495/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5465 | Val Acc: 0.9521
# Early stopping counter: 471/40
# Epoch [496/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5433 | Val Acc: 0.9542
# Early stopping counter: 472/40
# Epoch [497/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5480 | Val Acc: 0.9521
# Early stopping counter: 473/40
# Epoch [498/500] Train Loss: 0.0001 | Train Acc: 1.0000 | Val Loss: 0.5473 | Val Acc: 0.9501
# Early stopping counter: 474/40
# Epoch [499/500] Train Loss: 0.0000 | Train Acc: 1.0000 | Val Loss: 0.5489 | Val Acc: 0.9532
# Early stopping counter: 475/40
# Epoch [500/500] Train Loss: 0.0001 | Train Acc: 0.9999 | Val Loss: 0.5598 | Val Acc: 0.9511
# Early stopping counter: 476/40
#
# ================ Test Result ================
# Test Loss: 0.12427288480103016
# Test Accuracy: 0.9604166666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       320
#            1       0.95      0.96      0.95       320
#            2       0.97      0.93      0.95       320
#
#     accuracy                           0.96       960
#    macro avg       0.96      0.96      0.96       960
# weighted avg       0.96      0.96      0.96       960
#
#
# Confusion Matrix:
# [[316   1   3]
#  [  6 307   7]
#  [  5  16 299]]
#
# Training history saved.
# Best model saved as: best_gaf_cnn_vit_mlp_model.pth

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

save_path = "best_gaf_cnn_vit_mlp_model.pth"

checkpoint = torch.load(save_path, map_location=device)

model.load_state_dict(checkpoint["model_state_dict"])
model.to(device)
model.eval()

print("Best model loaded successfully.")
# Out:
# Best model loaded successfully.

# %%
all_labels = []
all_preds = []
all_probs = []

model.eval()

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        outputs = model(X_batch)

        probs = torch.softmax(outputs, dim=1)
        preds = torch.argmax(probs, dim=1)

        all_labels.extend(y_batch.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

y_true = np.array(all_labels)
y_pred = np.array(all_preds)
y_prob = np.array(all_probs)

print("Prediction finished.")
print("y_true shape:", y_true.shape)
print("y_pred shape:", y_pred.shape)
print("y_prob shape:", y_prob.shape)
# Out:
# Prediction finished.
# y_true shape: (960,)
# y_pred shape: (960,)
# y_prob shape: (960, 3)

# %%
cm = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[316   1   3]
#  [  6 307   7]
#  [  5  16 299]]

# %%
plt.figure(figsize=(6, 5))
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.colorbar()

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.tight_layout()
plt.savefig("confusion_matrix.png", dpi=300)
plt.show()
