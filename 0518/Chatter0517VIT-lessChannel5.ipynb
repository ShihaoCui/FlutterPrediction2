# %% [markdown]
# # 1. Load Data

# %%
import random
import numpy as np
import torch
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# =========================================================
# 0. Set random seed
# =========================================================

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


set_seed(42)


# =========================================================
# 1. Basic settings
# =========================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

npz_path = "GAF_ReSplitDatasets.npz"

batch_size = 32
num_epochs = 250
learning_rate = 1e-4
weight_decay = 5e-4
patience = 40

# Ch5 cutting force signal only
save_path = "best_gaf_cnn_vit_mlp_ch5_force1_improved_model.pth"


# =========================================================
# 2. Load npz data
# =========================================================

data = np.load(npz_path)

X_train = data["X_train"]
y_train = data["y_train"]

X_val = data["X_val"]
y_val = data["y_val"]

X_test = data["X_test"]
y_test = data["y_test"]

print("Original X_train shape:", X_train.shape)
print("Original y_train shape:", y_train.shape)
print("Original X_val shape:", X_val.shape)
print("Original y_val shape:", y_val.shape)
print("Original X_test shape:", X_test.shape)
print("Original y_test shape:", y_test.shape)


# =========================================================
# 3. Label processing
# =========================================================

if len(y_train.shape) > 1:
    y_train = np.argmax(y_train, axis=1)
    y_val = np.argmax(y_val, axis=1)
    y_test = np.argmax(y_test, axis=1)

y_train = y_train.astype(np.int64)
y_val = y_val.astype(np.int64)
y_test = y_test.astype(np.int64)

num_classes = len(np.unique(y_train))
print("Number of classes:", num_classes)


# =========================================================
# 4. Utility function: convert to Ch5 NCHW format
# =========================================================

def convert_to_ch5_force1_nchw(X):
    """
    Convert input GAF data to Ch5-only format.

    Used channel:
        Ch5

    This corresponds to:
        one cutting force signal

    Python channel index:
        Ch1 -> 0
        Ch2 -> 1
        Ch3 -> 2
        Ch4 -> 3
        Ch5 -> 4
        Ch6 -> 5
        Ch7 -> 6

    Supported formats:
        1. (N, 64, 64, 7)  -> NHWC
        2. (N, 7, 64, 64)  -> NCHW
        3. (N, 64, 7, 64)  -> NHCW

    Output:
        (N, 1, 64, 64)
    """

    X = X.astype(np.float32)

    if X.ndim != 4:
        raise ValueError(f"Unexpected X dimension: {X.shape}")

    # Case 1: NHWC, (N, 64, 64, 7)
    # Keep Ch5 only: index 4
    # Use 4:5, not 4, to keep channel dimension
    if X.shape[1:] == (64, 64, 7):
        X = X[:, :, :, 4:5]
        X = np.transpose(X, (0, 3, 1, 2))

    # Case 2: NCHW, (N, 7, 64, 64)
    elif X.shape[1:] == (7, 64, 64):
        X = X[:, 4:5, :, :]

    # Case 3: NHCW, (N, 64, 7, 64)
    elif X.shape[1:] == (64, 7, 64):
        X = X[:, :, 4:5, :]
        X = np.transpose(X, (0, 2, 1, 3))

    else:
        raise ValueError(f"Unexpected X shape: {X.shape}")

    return X


# Convert all datasets to (N, 1, 64, 64)
X_train = convert_to_ch5_force1_nchw(X_train)
X_val = convert_to_ch5_force1_nchw(X_val)
X_test = convert_to_ch5_force1_nchw(X_test)

print("Converted X_train shape:", X_train.shape)
print("Converted X_val shape:", X_val.shape)
print("Converted X_test shape:", X_test.shape)


# =========================================================
# 5. Channel-wise normalization
# =========================================================
# Only use training set to calculate mean and std

train_mean = X_train.mean(axis=(0, 2, 3), keepdims=True)
train_std = X_train.std(axis=(0, 2, 3), keepdims=True) + 1e-8

print("Train mean:", train_mean.reshape(-1))
print("Train std:", train_std.reshape(-1))

X_train = (X_train - train_mean) / train_std
X_val = (X_val - train_mean) / train_std
X_test = (X_test - train_mean) / train_std


# =========================================================
# 6. Dataset definition
# =========================================================

class GAFDataset(Dataset):
    def __init__(self, X, y, augment=False, noise_std=0.01, noise_prob=0.5):
        """
        Input X shape:
            (N, 1, 64, 64)

        Only Ch5 is used:
            one cutting force signal
        """

        self.X = X.astype(np.float32)
        self.y = y.astype(np.int64)

        self.augment = augment
        self.noise_std = noise_std
        self.noise_prob = noise_prob

        print("Dataset X shape:", self.X.shape)
        print("Use channel: Ch5 cutting force signal only")
        print("Augmentation:", self.augment)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y = self.y[idx]

        x = torch.tensor(x, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.long)

        if self.augment:
            x = self.add_light_noise(x)
            x = self.random_intensity_scale(x)

        return x, y

    def add_light_noise(self, x):
        """
        Add light Gaussian noise.
        Since data have been standardized, noise_std=0.01 is mild.
        """

        if torch.rand(1).item() < self.noise_prob:
            noise = self.noise_std * torch.randn_like(x)
            x = x + noise

        return x

    def random_intensity_scale(self, x):
        """
        Randomly scale the GAF intensity slightly.
        This improves robustness without changing the label.
        """

        if torch.rand(1).item() < 0.5:
            scale = 1.0 + 0.05 * torch.randn(1).item()
            x = x * scale

        return x


# =========================================================
# 7. Build Dataset and DataLoader
# =========================================================

train_dataset = GAFDataset(
    X_train,
    y_train,
    augment=True,
    noise_std=0.01,
    noise_prob=0.5
)

val_dataset = GAFDataset(
    X_val,
    y_val,
    augment=False
)

test_dataset = GAFDataset(
    X_test,
    y_test,
    augment=False
)

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0
)


# =========================================================
# 8. CNN + ViT + MLP Model
# =========================================================

class CNNFeatureExtractor(nn.Module):
    def __init__(self, in_channels=1, out_channels=128, dropout2d=0.10):
        super(CNNFeatureExtractor, self).__init__()

        self.cnn = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.GELU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(dropout2d),
            # 64 x 64 -> 32 x 32

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.GELU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(dropout2d),
            # 32 x 32 -> 16 x 16

            nn.Conv2d(64, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.GELU()
            # Output: 128 x 16 x 16
        )

    def forward(self, x):
        return self.cnn(x)


class PatchEmbedding(nn.Module):
    def __init__(self, in_channels=128, embed_dim=128, patch_size=4):
        super(PatchEmbedding, self).__init__()

        self.proj = nn.Conv2d(
            in_channels=in_channels,
            out_channels=embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2)
        x = x.transpose(1, 2)
        return x


class GAF_CNN_ViT_MLP(nn.Module):
    def __init__(
        self,
        in_channels=1,
        num_classes=3,
        cnn_out_channels=128,
        embed_dim=128,
        patch_size=4,
        num_heads=4,
        num_transformer_layers=2,
        mlp_hidden_dim=128,
        dropout=0.25
    ):
        super(GAF_CNN_ViT_MLP, self).__init__()

        self.cnn = CNNFeatureExtractor(
            in_channels=in_channels,
            out_channels=cnn_out_channels,
            dropout2d=0.10
        )

        self.patch_embed = PatchEmbedding(
            in_channels=cnn_out_channels,
            embed_dim=embed_dim,
            patch_size=patch_size
        )

        num_patches = (16 // patch_size) * (16 // patch_size)

        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))

        self.pos_embedding = nn.Parameter(
            torch.zeros(1, num_patches + 1, embed_dim)
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=embed_dim * 4,
            dropout=dropout,
            batch_first=True,
            activation="gelu"
        )

        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_transformer_layers
        )

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(embed_dim),
            nn.Linear(embed_dim, mlp_hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(mlp_hidden_dim, num_classes)
        )

        self._init_weights()

    def _init_weights(self):
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        nn.init.trunc_normal_(self.pos_embedding, std=0.02)

    def forward(self, x):
        """
        Input:
            x shape: (B, 1, 64, 64)
        """

        x = self.cnn(x)
        x = self.patch_embed(x)

        batch_size = x.shape[0]

        cls_tokens = self.cls_token.expand(batch_size, -1, -1)

        x = torch.cat((cls_tokens, x), dim=1)

        x = x + self.pos_embedding

        x = self.transformer(x)

        cls_output = x[:, 0]

        out = self.mlp_head(cls_output)

        return out


# =========================================================
# 9. Build model
# =========================================================

model = GAF_CNN_ViT_MLP(
    in_channels=1,
    num_classes=num_classes,
    cnn_out_channels=128,
    embed_dim=128,
    patch_size=4,
    num_heads=4,
    num_transformer_layers=2,
    mlp_hidden_dim=128,
    dropout=0.25
).to(device)

print(model)


# =========================================================
# 10. Loss function, optimizer, and scheduler
# =========================================================

criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="max",
    factor=0.5,
    patience=15
)


# =========================================================
# 11. Training and evaluation functions
# =========================================================

def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_loss = 0.0
    all_preds = []
    all_labels = []

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()

        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)

        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)

        optimizer.step()

        running_loss += loss.item() * X_batch.size(0)

        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(y_batch.detach().cpu().numpy())

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = accuracy_score(all_labels, all_preds)

    return epoch_loss, epoch_acc


def evaluate(model, loader, criterion, device):
    model.eval()

    running_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            running_loss += loss.item() * X_batch.size(0)

            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.detach().cpu().numpy())
            all_labels.extend(y_batch.detach().cpu().numpy())

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = accuracy_score(all_labels, all_preds)

    return epoch_loss, epoch_acc, np.array(all_labels), np.array(all_preds)


# =========================================================
# 12. Training loop
# =========================================================

best_val_acc = 0.0
best_val_loss = np.inf
early_stop_counter = 0

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": [],
    "lr": []
}

for epoch in range(num_epochs):

    train_loss, train_acc = train_one_epoch(
        model,
        train_loader,
        criterion,
        optimizer,
        device
    )

    val_loss, val_acc, _, _ = evaluate(
        model,
        val_loader,
        criterion,
        device
    )

    scheduler.step(val_acc)

    current_lr = optimizer.param_groups[0]["lr"]

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)
    history["lr"].append(current_lr)

    print(
        f"Epoch [{epoch + 1:03d}/{num_epochs}] "
        f"Train Loss: {train_loss:.4f} | "
        f"Train Acc: {train_acc:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Val Acc: {val_acc:.4f} | "
        f"LR: {current_lr:.8f}"
    )

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_val_loss = val_loss
        early_stop_counter = 0

        torch.save(
            {
                "model_state_dict": model.state_dict(),
                "num_classes": num_classes,
                "history": history,
                "best_val_loss": best_val_loss,
                "best_val_acc": best_val_acc,
                "input_channels": 1,
                "used_channels": "Ch5 cutting force signal",
                "train_mean": train_mean,
                "train_std": train_std
            },
            save_path
        )

        print("Best model saved.")

    else:
        early_stop_counter += 1
        print(f"Early stopping counter: {early_stop_counter}/{patience}")

        if early_stop_counter >= patience:
            print("Early stopping triggered.")
            break


# =========================================================
# 13. Load best model and evaluate on test set
# =========================================================

checkpoint = torch.load(save_path, map_location=device)
model.load_state_dict(checkpoint["model_state_dict"])

test_loss, test_acc, y_true, y_pred = evaluate(
    model,
    test_loader,
    criterion,
    device
)

print("\n================ Best Validation Result ================")
print("Best Val Loss:", checkpoint["best_val_loss"])
print("Best Val Accuracy:", checkpoint["best_val_acc"])

print("\n================ Test Result ================")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, digits=4))

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))


# =========================================================
# 14. Save training history
# =========================================================

np.savez(
    "training_history_gaf_cnn_vit_mlp_ch5_force1_improved.npz",
    train_loss=np.array(history["train_loss"]),
    train_acc=np.array(history["train_acc"]),
    val_loss=np.array(history["val_loss"]),
    val_acc=np.array(history["val_acc"]),
    lr=np.array(history["lr"])
)

print("\nTraining history saved.")
print("Training history saved as: training_history_gaf_cnn_vit_mlp_ch5_force1_improved.npz")
print("Best model saved as:", save_path)
# Out:
# Using device: cuda
# Original X_train shape: (7679, 7, 64, 64)
# Original y_train shape: (7679,)
# Original X_val shape: (961, 7, 64, 64)
# Original y_val shape: (961,)
# Original X_test shape: (960, 7, 64, 64)
# Original y_test shape: (960,)
# Number of classes: 3
# Converted X_train shape: (7679, 1, 64, 64)
# Converted X_val shape: (961, 1, 64, 64)
# Converted X_test shape: (960, 1, 64, 64)
# Train mean: [-0.65496343]
# Train std: [0.34897968]
# Dataset X shape: (7679, 1, 64, 64)
# Use channel: Ch5 cutting force signal only
# Augmentation: True
# Dataset X shape: (961, 1, 64, 64)
# Use channel: Ch5 cutting force signal only
# Augmentation: False
# Dataset X shape: (960, 1, 64, 64)
# Use channel: Ch5 cutting force signal only
# Augmentation: False
# GAF_CNN_ViT_MLP(
#   (cnn): CNNFeatureExtractor(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Dropout2d(p=0.1, inplace=False)
#       (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): GELU(approximate='none')
#       (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (9): Dropout2d(p=0.1, inplace=False)
#       (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): GELU(approximate='none')
#     )
#   )
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(128, 128, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.25, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.25, inplace=False)
#         (dropout2): Dropout(p=0.25, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# Epoch [001/250] Train Loss: 0.8607 | Train Acc: 0.6105 | Val Loss: 0.6779 | Val Acc: 0.7357 | LR: 0.00010000
# Best model saved.
# Epoch [002/250] Train Loss: 0.7070 | Train Acc: 0.7092 | Val Loss: 0.6047 | Val Acc: 0.7284 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [003/250] Train Loss: 0.6255 | Train Acc: 0.7574 | Val Loss: 0.5473 | Val Acc: 0.7981 | LR: 0.00010000
# Best model saved.
# Epoch [004/250] Train Loss: 0.5762 | Train Acc: 0.7856 | Val Loss: 0.5041 | Val Acc: 0.8304 | LR: 0.00010000
# Best model saved.
# Epoch [005/250] Train Loss: 0.5433 | Train Acc: 0.8024 | Val Loss: 0.4721 | Val Acc: 0.8450 | LR: 0.00010000
# Best model saved.
# Epoch [006/250] Train Loss: 0.5099 | Train Acc: 0.8247 | Val Loss: 0.4518 | Val Acc: 0.8470 | LR: 0.00010000
# Best model saved.
# Epoch [007/250] Train Loss: 0.4757 | Train Acc: 0.8446 | Val Loss: 0.4272 | Val Acc: 0.8689 | LR: 0.00010000
# Best model saved.
# Epoch [008/250] Train Loss: 0.4533 | Train Acc: 0.8545 | Val Loss: 0.4458 | Val Acc: 0.8512 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [009/250] Train Loss: 0.4402 | Train Acc: 0.8612 | Val Loss: 0.3965 | Val Acc: 0.8668 | LR: 0.00010000
# Early stopping counter: 2/40
# Epoch [010/250] Train Loss: 0.4196 | Train Acc: 0.8756 | Val Loss: 0.3975 | Val Acc: 0.8803 | LR: 0.00010000
# Best model saved.
# Epoch [011/250] Train Loss: 0.4054 | Train Acc: 0.8739 | Val Loss: 0.3898 | Val Acc: 0.8772 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [012/250] Train Loss: 0.3860 | Train Acc: 0.8920 | Val Loss: 0.3929 | Val Acc: 0.8824 | LR: 0.00010000
# Best model saved.
# Epoch [013/250] Train Loss: 0.3841 | Train Acc: 0.8893 | Val Loss: 0.3766 | Val Acc: 0.8845 | LR: 0.00010000
# Best model saved.
# Epoch [014/250] Train Loss: 0.3705 | Train Acc: 0.8958 | Val Loss: 0.3793 | Val Acc: 0.8939 | LR: 0.00010000
# Best model saved.
# Epoch [015/250] Train Loss: 0.3633 | Train Acc: 0.9034 | Val Loss: 0.3800 | Val Acc: 0.8803 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [016/250] Train Loss: 0.3508 | Train Acc: 0.9096 | Val Loss: 0.3543 | Val Acc: 0.9032 | LR: 0.00010000
# Best model saved.
# Epoch [017/250] Train Loss: 0.3471 | Train Acc: 0.9150 | Val Loss: 0.3585 | Val Acc: 0.9032 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [018/250] Train Loss: 0.3344 | Train Acc: 0.9202 | Val Loss: 0.3536 | Val Acc: 0.9053 | LR: 0.00010000
# Best model saved.
# Epoch [019/250] Train Loss: 0.3315 | Train Acc: 0.9167 | Val Loss: 0.3686 | Val Acc: 0.8970 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [020/250] Train Loss: 0.3253 | Train Acc: 0.9224 | Val Loss: 0.3506 | Val Acc: 0.9022 | LR: 0.00010000
# Early stopping counter: 2/40
# Epoch [021/250] Train Loss: 0.3207 | Train Acc: 0.9239 | Val Loss: 0.3621 | Val Acc: 0.9053 | LR: 0.00010000
# Early stopping counter: 3/40
# Epoch [022/250] Train Loss: 0.3139 | Train Acc: 0.9259 | Val Loss: 0.3639 | Val Acc: 0.9011 | LR: 0.00010000
# Early stopping counter: 4/40
# Epoch [023/250] Train Loss: 0.3132 | Train Acc: 0.9309 | Val Loss: 0.3525 | Val Acc: 0.9084 | LR: 0.00010000
# Best model saved.
# Epoch [024/250] Train Loss: 0.2993 | Train Acc: 0.9346 | Val Loss: 0.3555 | Val Acc: 0.9043 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [025/250] Train Loss: 0.3068 | Train Acc: 0.9323 | Val Loss: 0.3523 | Val Acc: 0.9063 | LR: 0.00010000
# Early stopping counter: 2/40
# Epoch [026/250] Train Loss: 0.2948 | Train Acc: 0.9393 | Val Loss: 0.3784 | Val Acc: 0.8991 | LR: 0.00010000
# Early stopping counter: 3/40
# Epoch [027/250] Train Loss: 0.2873 | Train Acc: 0.9435 | Val Loss: 0.4033 | Val Acc: 0.8959 | LR: 0.00010000
# Early stopping counter: 4/40
# Epoch [028/250] Train Loss: 0.2831 | Train Acc: 0.9471 | Val Loss: 0.3853 | Val Acc: 0.8949 | LR: 0.00010000
# Early stopping counter: 5/40
# Epoch [029/250] Train Loss: 0.2801 | Train Acc: 0.9479 | Val Loss: 0.3800 | Val Acc: 0.9011 | LR: 0.00010000
# Early stopping counter: 6/40
# Epoch [030/250] Train Loss: 0.2754 | Train Acc: 0.9517 | Val Loss: 0.3832 | Val Acc: 0.9095 | LR: 0.00010000
# Best model saved.
# Epoch [031/250] Train Loss: 0.2766 | Train Acc: 0.9501 | Val Loss: 0.3703 | Val Acc: 0.9105 | LR: 0.00010000
# Best model saved.
# Epoch [032/250] Train Loss: 0.2678 | Train Acc: 0.9542 | Val Loss: 0.4088 | Val Acc: 0.9022 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [033/250] Train Loss: 0.2650 | Train Acc: 0.9562 | Val Loss: 0.3618 | Val Acc: 0.9168 | LR: 0.00010000
# Best model saved.
# Epoch [034/250] Train Loss: 0.2613 | Train Acc: 0.9581 | Val Loss: 0.3792 | Val Acc: 0.9126 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [035/250] Train Loss: 0.2592 | Train Acc: 0.9578 | Val Loss: 0.3922 | Val Acc: 0.9053 | LR: 0.00010000
# Early stopping counter: 2/40
# Epoch [036/250] Train Loss: 0.2591 | Train Acc: 0.9578 | Val Loss: 0.3752 | Val Acc: 0.9105 | LR: 0.00010000
# Early stopping counter: 3/40
# Epoch [037/250] Train Loss: 0.2537 | Train Acc: 0.9604 | Val Loss: 0.3663 | Val Acc: 0.9157 | LR: 0.00010000
# Early stopping counter: 4/40
# Epoch [038/250] Train Loss: 0.2518 | Train Acc: 0.9602 | Val Loss: 0.3662 | Val Acc: 0.9209 | LR: 0.00010000
# Best model saved.
# Epoch [039/250] Train Loss: 0.2409 | Train Acc: 0.9672 | Val Loss: 0.3991 | Val Acc: 0.9136 | LR: 0.00010000
# Early stopping counter: 1/40
# Epoch [040/250] Train Loss: 0.2452 | Train Acc: 0.9656 | Val Loss: 0.3907 | Val Acc: 0.9074 | LR: 0.00010000
# Early stopping counter: 2/40
# Epoch [041/250] Train Loss: 0.2390 | Train Acc: 0.9668 | Val Loss: 0.3918 | Val Acc: 0.9168 | LR: 0.00010000
# Early stopping counter: 3/40
# Epoch [042/250] Train Loss: 0.2363 | Train Acc: 0.9699 | Val Loss: 0.3869 | Val Acc: 0.9178 | LR: 0.00010000
# Early stopping counter: 4/40
# Epoch [043/250] Train Loss: 0.2380 | Train Acc: 0.9693 | Val Loss: 0.3987 | Val Acc: 0.9188 | LR: 0.00010000
# Early stopping counter: 5/40
# Epoch [044/250] Train Loss: 0.2403 | Train Acc: 0.9671 | Val Loss: 0.3909 | Val Acc: 0.9136 | LR: 0.00010000
# Early stopping counter: 6/40
# Epoch [045/250] Train Loss: 0.2361 | Train Acc: 0.9690 | Val Loss: 0.3829 | Val Acc: 0.9147 | LR: 0.00010000
# Early stopping counter: 7/40
# Epoch [046/250] Train Loss: 0.2269 | Train Acc: 0.9763 | Val Loss: 0.3864 | Val Acc: 0.9188 | LR: 0.00010000
# Early stopping counter: 8/40
# Epoch [047/250] Train Loss: 0.2289 | Train Acc: 0.9720 | Val Loss: 0.3974 | Val Acc: 0.9168 | LR: 0.00010000
# Early stopping counter: 9/40
# Epoch [048/250] Train Loss: 0.2280 | Train Acc: 0.9720 | Val Loss: 0.3899 | Val Acc: 0.9168 | LR: 0.00010000
# Early stopping counter: 10/40
# Epoch [049/250] Train Loss: 0.2229 | Train Acc: 0.9770 | Val Loss: 0.3927 | Val Acc: 0.9168 | LR: 0.00010000
# Early stopping counter: 11/40
# Epoch [050/250] Train Loss: 0.2221 | Train Acc: 0.9764 | Val Loss: 0.3944 | Val Acc: 0.9188 | LR: 0.00010000
# Early stopping counter: 12/40
# Epoch [051/250] Train Loss: 0.2245 | Train Acc: 0.9749 | Val Loss: 0.3976 | Val Acc: 0.9188 | LR: 0.00010000
# Early stopping counter: 13/40
# Epoch [052/250] Train Loss: 0.2208 | Train Acc: 0.9781 | Val Loss: 0.3892 | Val Acc: 0.9168 | LR: 0.00010000
# Early stopping counter: 14/40
# Epoch [053/250] Train Loss: 0.2255 | Train Acc: 0.9741 | Val Loss: 0.4236 | Val Acc: 0.9147 | LR: 0.00010000
# Early stopping counter: 15/40
# Epoch [054/250] Train Loss: 0.2154 | Train Acc: 0.9799 | Val Loss: 0.3898 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 16/40
# Epoch [055/250] Train Loss: 0.2122 | Train Acc: 0.9822 | Val Loss: 0.4064 | Val Acc: 0.9168 | LR: 0.00005000
# Early stopping counter: 17/40
# Epoch [056/250] Train Loss: 0.2041 | Train Acc: 0.9853 | Val Loss: 0.4007 | Val Acc: 0.9199 | LR: 0.00005000
# Early stopping counter: 18/40
# Epoch [057/250] Train Loss: 0.2022 | Train Acc: 0.9874 | Val Loss: 0.4138 | Val Acc: 0.9168 | LR: 0.00005000
# Early stopping counter: 19/40
# Epoch [058/250] Train Loss: 0.2041 | Train Acc: 0.9845 | Val Loss: 0.4048 | Val Acc: 0.9178 | LR: 0.00005000
# Early stopping counter: 20/40
# Epoch [059/250] Train Loss: 0.2044 | Train Acc: 0.9866 | Val Loss: 0.4125 | Val Acc: 0.9240 | LR: 0.00005000
# Best model saved.
# Epoch [060/250] Train Loss: 0.1972 | Train Acc: 0.9885 | Val Loss: 0.4113 | Val Acc: 0.9220 | LR: 0.00005000
# Early stopping counter: 1/40
# Epoch [061/250] Train Loss: 0.1963 | Train Acc: 0.9893 | Val Loss: 0.4180 | Val Acc: 0.9178 | LR: 0.00005000
# Early stopping counter: 2/40
# Epoch [062/250] Train Loss: 0.1975 | Train Acc: 0.9889 | Val Loss: 0.4262 | Val Acc: 0.9168 | LR: 0.00005000
# Early stopping counter: 3/40
# Epoch [063/250] Train Loss: 0.1965 | Train Acc: 0.9895 | Val Loss: 0.4185 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 4/40
# Epoch [064/250] Train Loss: 0.1971 | Train Acc: 0.9880 | Val Loss: 0.4109 | Val Acc: 0.9220 | LR: 0.00005000
# Early stopping counter: 5/40
# Epoch [065/250] Train Loss: 0.1980 | Train Acc: 0.9883 | Val Loss: 0.4092 | Val Acc: 0.9199 | LR: 0.00005000
# Early stopping counter: 6/40
# Epoch [066/250] Train Loss: 0.1982 | Train Acc: 0.9880 | Val Loss: 0.4256 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 7/40
# Epoch [067/250] Train Loss: 0.1933 | Train Acc: 0.9897 | Val Loss: 0.4561 | Val Acc: 0.9126 | LR: 0.00005000
# Early stopping counter: 8/40
# Epoch [068/250] Train Loss: 0.1988 | Train Acc: 0.9883 | Val Loss: 0.4246 | Val Acc: 0.9230 | LR: 0.00005000
# Early stopping counter: 9/40
# Epoch [069/250] Train Loss: 0.1955 | Train Acc: 0.9891 | Val Loss: 0.4196 | Val Acc: 0.9199 | LR: 0.00005000
# Early stopping counter: 10/40
# Epoch [070/250] Train Loss: 0.1920 | Train Acc: 0.9917 | Val Loss: 0.4153 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 11/40
# Epoch [071/250] Train Loss: 0.1934 | Train Acc: 0.9896 | Val Loss: 0.3988 | Val Acc: 0.9220 | LR: 0.00005000
# Early stopping counter: 12/40
# Epoch [072/250] Train Loss: 0.1953 | Train Acc: 0.9896 | Val Loss: 0.4124 | Val Acc: 0.9261 | LR: 0.00005000
# Best model saved.
# Epoch [073/250] Train Loss: 0.1939 | Train Acc: 0.9898 | Val Loss: 0.4249 | Val Acc: 0.9188 | LR: 0.00005000
# Early stopping counter: 1/40
# Epoch [074/250] Train Loss: 0.1941 | Train Acc: 0.9910 | Val Loss: 0.4125 | Val Acc: 0.9157 | LR: 0.00005000
# Early stopping counter: 2/40
# Epoch [075/250] Train Loss: 0.1956 | Train Acc: 0.9895 | Val Loss: 0.4288 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 3/40
# Epoch [076/250] Train Loss: 0.1902 | Train Acc: 0.9922 | Val Loss: 0.4313 | Val Acc: 0.9178 | LR: 0.00005000
# Early stopping counter: 4/40
# Epoch [077/250] Train Loss: 0.1943 | Train Acc: 0.9900 | Val Loss: 0.4395 | Val Acc: 0.9188 | LR: 0.00005000
# Early stopping counter: 5/40
# Epoch [078/250] Train Loss: 0.1942 | Train Acc: 0.9900 | Val Loss: 0.4233 | Val Acc: 0.9157 | LR: 0.00005000
# Early stopping counter: 6/40
# Epoch [079/250] Train Loss: 0.1916 | Train Acc: 0.9911 | Val Loss: 0.4203 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 7/40
# Epoch [080/250] Train Loss: 0.1918 | Train Acc: 0.9911 | Val Loss: 0.4474 | Val Acc: 0.9126 | LR: 0.00005000
# Early stopping counter: 8/40
# Epoch [081/250] Train Loss: 0.1905 | Train Acc: 0.9915 | Val Loss: 0.4321 | Val Acc: 0.9188 | LR: 0.00005000
# Early stopping counter: 9/40
# Epoch [082/250] Train Loss: 0.1899 | Train Acc: 0.9917 | Val Loss: 0.4432 | Val Acc: 0.9168 | LR: 0.00005000
# Early stopping counter: 10/40
# Epoch [083/250] Train Loss: 0.1887 | Train Acc: 0.9917 | Val Loss: 0.4438 | Val Acc: 0.9209 | LR: 0.00005000
# Early stopping counter: 11/40
# Epoch [084/250] Train Loss: 0.1897 | Train Acc: 0.9914 | Val Loss: 0.4354 | Val Acc: 0.9136 | LR: 0.00005000
# Early stopping counter: 12/40
# Epoch [085/250] Train Loss: 0.1900 | Train Acc: 0.9918 | Val Loss: 0.4220 | Val Acc: 0.9188 | LR: 0.00005000
# Early stopping counter: 13/40
# Epoch [086/250] Train Loss: 0.1887 | Train Acc: 0.9919 | Val Loss: 0.4326 | Val Acc: 0.9157 | LR: 0.00005000
# Early stopping counter: 14/40
# Epoch [087/250] Train Loss: 0.1881 | Train Acc: 0.9928 | Val Loss: 0.4274 | Val Acc: 0.9178 | LR: 0.00005000
# Early stopping counter: 15/40
# Epoch [088/250] Train Loss: 0.1908 | Train Acc: 0.9918 | Val Loss: 0.4277 | Val Acc: 0.9220 | LR: 0.00002500
# Early stopping counter: 16/40
# Epoch [089/250] Train Loss: 0.1861 | Train Acc: 0.9939 | Val Loss: 0.4193 | Val Acc: 0.9282 | LR: 0.00002500
# Best model saved.
# Epoch [090/250] Train Loss: 0.1851 | Train Acc: 0.9943 | Val Loss: 0.4269 | Val Acc: 0.9230 | LR: 0.00002500
# Early stopping counter: 1/40
# Epoch [091/250] Train Loss: 0.1854 | Train Acc: 0.9939 | Val Loss: 0.4362 | Val Acc: 0.9230 | LR: 0.00002500
# Early stopping counter: 2/40
# Epoch [092/250] Train Loss: 0.1829 | Train Acc: 0.9951 | Val Loss: 0.4196 | Val Acc: 0.9261 | LR: 0.00002500
# Early stopping counter: 3/40
# Epoch [093/250] Train Loss: 0.1836 | Train Acc: 0.9945 | Val Loss: 0.4194 | Val Acc: 0.9240 | LR: 0.00002500
# Early stopping counter: 4/40
# Epoch [094/250] Train Loss: 0.1797 | Train Acc: 0.9964 | Val Loss: 0.4189 | Val Acc: 0.9251 | LR: 0.00002500
# Early stopping counter: 5/40
# Epoch [095/250] Train Loss: 0.1797 | Train Acc: 0.9961 | Val Loss: 0.4359 | Val Acc: 0.9209 | LR: 0.00002500
# Early stopping counter: 6/40
# Epoch [096/250] Train Loss: 0.1849 | Train Acc: 0.9944 | Val Loss: 0.4294 | Val Acc: 0.9220 | LR: 0.00002500
# Early stopping counter: 7/40
# Epoch [097/250] Train Loss: 0.1839 | Train Acc: 0.9951 | Val Loss: 0.4463 | Val Acc: 0.9168 | LR: 0.00002500
# Early stopping counter: 8/40
# Epoch [098/250] Train Loss: 0.1822 | Train Acc: 0.9952 | Val Loss: 0.4420 | Val Acc: 0.9168 | LR: 0.00002500
# Early stopping counter: 9/40
# Epoch [099/250] Train Loss: 0.1812 | Train Acc: 0.9960 | Val Loss: 0.4489 | Val Acc: 0.9178 | LR: 0.00002500
# Early stopping counter: 10/40
# Epoch [100/250] Train Loss: 0.1805 | Train Acc: 0.9957 | Val Loss: 0.4431 | Val Acc: 0.9220 | LR: 0.00002500
# Early stopping counter: 11/40
# Epoch [101/250] Train Loss: 0.1824 | Train Acc: 0.9947 | Val Loss: 0.4516 | Val Acc: 0.9147 | LR: 0.00002500
# Early stopping counter: 12/40
# Epoch [102/250] Train Loss: 0.1817 | Train Acc: 0.9954 | Val Loss: 0.4380 | Val Acc: 0.9188 | LR: 0.00002500
# Early stopping counter: 13/40
# Epoch [103/250] Train Loss: 0.1824 | Train Acc: 0.9949 | Val Loss: 0.4272 | Val Acc: 0.9199 | LR: 0.00002500
# Early stopping counter: 14/40
# Epoch [104/250] Train Loss: 0.1820 | Train Acc: 0.9951 | Val Loss: 0.4385 | Val Acc: 0.9147 | LR: 0.00002500
# Early stopping counter: 15/40
# Epoch [105/250] Train Loss: 0.1806 | Train Acc: 0.9961 | Val Loss: 0.4508 | Val Acc: 0.9209 | LR: 0.00001250
# Early stopping counter: 16/40
# Epoch [106/250] Train Loss: 0.1819 | Train Acc: 0.9960 | Val Loss: 0.4431 | Val Acc: 0.9188 | LR: 0.00001250
# Early stopping counter: 17/40
# Epoch [107/250] Train Loss: 0.1804 | Train Acc: 0.9964 | Val Loss: 0.4499 | Val Acc: 0.9188 | LR: 0.00001250
# Early stopping counter: 18/40
# Epoch [108/250] Train Loss: 0.1767 | Train Acc: 0.9977 | Val Loss: 0.4396 | Val Acc: 0.9209 | LR: 0.00001250
# Early stopping counter: 19/40
# Epoch [109/250] Train Loss: 0.1813 | Train Acc: 0.9964 | Val Loss: 0.4357 | Val Acc: 0.9209 | LR: 0.00001250
# Early stopping counter: 20/40
# Epoch [110/250] Train Loss: 0.1783 | Train Acc: 0.9973 | Val Loss: 0.4486 | Val Acc: 0.9199 | LR: 0.00001250
# Early stopping counter: 21/40
# Epoch [111/250] Train Loss: 0.1790 | Train Acc: 0.9971 | Val Loss: 0.4495 | Val Acc: 0.9230 | LR: 0.00001250
# Early stopping counter: 22/40
# Epoch [112/250] Train Loss: 0.1789 | Train Acc: 0.9967 | Val Loss: 0.4431 | Val Acc: 0.9168 | LR: 0.00001250
# Early stopping counter: 23/40
# Epoch [113/250] Train Loss: 0.1773 | Train Acc: 0.9975 | Val Loss: 0.4415 | Val Acc: 0.9230 | LR: 0.00001250
# Early stopping counter: 24/40
# Epoch [114/250] Train Loss: 0.1805 | Train Acc: 0.9960 | Val Loss: 0.4538 | Val Acc: 0.9188 | LR: 0.00001250
# Early stopping counter: 25/40
# Epoch [115/250] Train Loss: 0.1792 | Train Acc: 0.9964 | Val Loss: 0.4349 | Val Acc: 0.9261 | LR: 0.00001250
# Early stopping counter: 26/40
# Epoch [116/250] Train Loss: 0.1794 | Train Acc: 0.9961 | Val Loss: 0.4434 | Val Acc: 0.9188 | LR: 0.00001250
# Early stopping counter: 27/40
# Epoch [117/250] Train Loss: 0.1780 | Train Acc: 0.9967 | Val Loss: 0.4472 | Val Acc: 0.9168 | LR: 0.00001250
# Early stopping counter: 28/40
# Epoch [118/250] Train Loss: 0.1764 | Train Acc: 0.9982 | Val Loss: 0.4523 | Val Acc: 0.9178 | LR: 0.00001250
# Early stopping counter: 29/40
# Epoch [119/250] Train Loss: 0.1808 | Train Acc: 0.9965 | Val Loss: 0.4540 | Val Acc: 0.9188 | LR: 0.00001250
# Early stopping counter: 30/40
# Epoch [120/250] Train Loss: 0.1775 | Train Acc: 0.9974 | Val Loss: 0.4624 | Val Acc: 0.9126 | LR: 0.00001250
# Early stopping counter: 31/40
# Epoch [121/250] Train Loss: 0.1766 | Train Acc: 0.9975 | Val Loss: 0.4695 | Val Acc: 0.9136 | LR: 0.00000625
# Early stopping counter: 32/40
# Epoch [122/250] Train Loss: 0.1773 | Train Acc: 0.9975 | Val Loss: 0.4536 | Val Acc: 0.9199 | LR: 0.00000625
# Early stopping counter: 33/40
# Epoch [123/250] Train Loss: 0.1759 | Train Acc: 0.9978 | Val Loss: 0.4610 | Val Acc: 0.9168 | LR: 0.00000625
# Early stopping counter: 34/40
# Epoch [124/250] Train Loss: 0.1791 | Train Acc: 0.9964 | Val Loss: 0.4593 | Val Acc: 0.9157 | LR: 0.00000625
# Early stopping counter: 35/40
# Epoch [125/250] Train Loss: 0.1795 | Train Acc: 0.9969 | Val Loss: 0.4544 | Val Acc: 0.9178 | LR: 0.00000625
# Early stopping counter: 36/40
# Epoch [126/250] Train Loss: 0.1762 | Train Acc: 0.9979 | Val Loss: 0.4505 | Val Acc: 0.9188 | LR: 0.00000625
# Early stopping counter: 37/40
# Epoch [127/250] Train Loss: 0.1782 | Train Acc: 0.9974 | Val Loss: 0.4509 | Val Acc: 0.9209 | LR: 0.00000625
# Early stopping counter: 38/40
# Epoch [128/250] Train Loss: 0.1781 | Train Acc: 0.9969 | Val Loss: 0.4525 | Val Acc: 0.9157 | LR: 0.00000625
# Early stopping counter: 39/40
# Epoch [129/250] Train Loss: 0.1771 | Train Acc: 0.9977 | Val Loss: 0.4507 | Val Acc: 0.9188 | LR: 0.00000625
# Early stopping counter: 40/40
# Early stopping triggered.
#
# ================ Best Validation Result ================
# Best Val Loss: 0.41932554967879754
# Best Val Accuracy: 0.9281997918834547
#
# ================ Test Result ================
# Test Loss: 0.456196362276872
# Test Accuracy: 0.915625
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9871    0.9531    0.9698       320
#            1     0.8684    0.9281    0.8973       320
#            2     0.8964    0.8656    0.8808       320
#
#     accuracy                         0.9156       960
#    macro avg     0.9173    0.9156    0.9159       960
# weighted avg     0.9173    0.9156    0.9159       960
#
#
# Confusion Matrix:
# [[305   6   9]
#  [  0 297  23]
#  [  4  39 277]]
#
# Training history saved.
# Training history saved as: training_history_gaf_cnn_vit_mlp_ch5_force1_improved.npz
# Best model saved as: best_gaf_cnn_vit_mlp_ch5_force1_improved_model.pth

# %% [markdown]
# # confusion matrix

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

save_path = "best_gaf_cnn_vit_mlp_ch5_force1_improved_model.pth"

checkpoint = torch.load(save_path, map_location=device)

model.load_state_dict(checkpoint["model_state_dict"])
model.to(device)
model.eval()

print("Best model loaded successfully.")
# Out:
# Best model loaded successfully.

# %%
all_labels = []
all_preds = []
all_probs = []

model.eval()

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        outputs = model(X_batch)

        probs = torch.softmax(outputs, dim=1)
        preds = torch.argmax(probs, dim=1)

        all_labels.extend(y_batch.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

y_true = np.array(all_labels)
y_pred = np.array(all_preds)
y_prob = np.array(all_probs)

print("Prediction finished.")
print("y_true shape:", y_true.shape)
print("y_pred shape:", y_pred.shape)
print("y_prob shape:", y_prob.shape)
# Out:
# Prediction finished.
# y_true shape: (960,)
# y_pred shape: (960,)
# y_prob shape: (960, 3)

# %%
cm = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[305   6   9]
#  [  0 297  23]
#  [  4  39 277]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# =========================
# SCI-style global settings
# =========================
# plt.rcParams["font.family"] = "serif"
# plt.rcParams["font.serif"] = ["DejaVu Serif"]
# plt.rcParams["font.size"] = 12
# plt.rcParams["axes.labelsize"] = 14
# plt.rcParams["axes.titlesize"] = 14
# plt.rcParams["xtick.labelsize"] = 12
# plt.rcParams["ytick.labelsize"] = 12
# plt.rcParams["pdf.fonttype"] = 42
# plt.rcParams["ps.fonttype"] = 42

# =========================
# Class names
# =========================
class_names = ["0", "1", "2"]

# 如果你的类别想用 0, 1, 2，也可以用：
# class_names = ["0", "1", "2"]

# =========================
# Plot confusion matrix
# =========================
fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(cm, cmap="Blues")

# Colorbar
cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cbar.ax.tick_params(labelsize=12)

# Axis labels
ax.set_xlabel("Predicted label", fontsize=14)
ax.set_ylabel("True label", fontsize=14)

# Tick labels
ax.set_xticks(np.arange(len(class_names)))
ax.set_yticks(np.arange(len(class_names)))

ax.set_xticklabels(class_names, fontsize=12)
ax.set_yticklabels(class_names, fontsize=12)

# Rotate x-axis labels if needed
plt.setp(ax.get_xticklabels(), rotation=0, ha="center")

# Write values in each cell
threshold = cm.max() / 2.0

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        value = cm[i, j]
        text_color = "white" if value > threshold else "black"
        ax.text(
            j, i, str(value),
            ha="center",
            va="center",
            color=text_color,
            fontsize=13
        )

# Remove unnecessary frame style adjustment
for spine in ax.spines.values():
    spine.set_linewidth(1.0)

# Layout
plt.tight_layout()

# =========================
# Save high-quality figures
# =========================
fig.savefig("confusion_matrix.png", dpi=600, bbox_inches="tight")
fig.savefig("confusion_matrix.pdf", bbox_inches="tight")
fig.savefig("confusion_matrix.tiff", dpi=600, bbox_inches="tight")

plt.show()
